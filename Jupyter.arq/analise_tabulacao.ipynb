# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
import pandas as pd
import numpy as  np
import datetime as dt
import pandas as pd
import numpy as np
import datetime as dt

from Python_arq import engines as engs
from sqlalchemy import text
from calendar import day_name
from sqlalchemy import text
from pathlib import Path


eng = engs.get_engine()
text_qry = text(engs.load_query('tab_olos.sql'))
df = pd.read_sql(text_qry, eng)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       5 import numpy as np
#       6 import datetime as dt
# ----> 8 from Python_arq import engines as engs
#       9 from sqlalchemy import text
#      10 from calendar import day_name
#
# File c:\Users\wconceicao\OneDrive - Grupo A Educação SA\Área de Trabalho\Projetos\Python_arq\engines.py:5
#       3 from pathlib import Path
#       4 from dotenv import load_dotenv
# ----> 5 from db_config import DB_USER, DB_PASSWORD, DB_HOST, DB_PORT, DB_DATABASE
#       7 load_dotenv()
#       9 def get_engine():
#
# ModuleNotFoundError: No module named 'db_config'

# %%
tab_aut = df.groupby(['disposition_nivel_1','data']).agg(
    total = ('count','sum')
).reset_index()
tab_aut['total_mes'] = df.groupby('data').sum()
